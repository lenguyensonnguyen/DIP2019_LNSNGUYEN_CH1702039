# %% [markdown]
# <H3>
#     <P>XỬ LÝ ẢNH VÀ THỊ GIÁC MÁY TÍNH - 2019</P>
#     <P>LÊ NGUYỄN SƠN NGUYÊN - CH1702039</P>
#     <P>XỬ LÝ ẢNH NHIỄU SỐ 4</P>
# </H3>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.dpi'] = 500

# %%
# %matplotlib inline

# %%
img = cv2.imread('./Anh nhieu/4n.jpg', 0)

# %% [markdown]
# HIỂN THỊ ẢNH NHIỄU SỐ 4

# %%
plt.imshow(img, cmap='gray')

# %%
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)

magnitude_spectrum = 20*np.log(np.abs(fshift))
magnitude_spectrum = np.asarray(magnitude_spectrum, dtype=np.uint8)

img_and_magnitude = np.concatenate((img, magnitude_spectrum), axis=1)

# %%
plt.imshow(img_and_magnitude, cmap='gray')

# %%
plt.imshow(magnitude_spectrum, cmap='gray')

# %% [markdown]
# CHỌN MỘT VÙNG ẢNH ĐỒNG NHẤT

# %%
img_crop = cv2.imread("./Anh nhieu/4c.jpg", 0)

# %%
plt.imshow(img_crop, cmap='gray')

# %% [markdown]
# VẼ HISTOGRAM - XÁC ĐỊNH LOẠI NHIỄU LÀ NHIỄU GAUSSIAN

# %%
plt.hist(img_crop.ravel(), 256, [0, 256])
plt.show()

# %%
denoise = cv2.fastNlMeansDenoising(img, None, 3, 5, 15)

# %%
plt.imshow(denoise, cmap='gray')

# %%
cv2.imwrite('./Anh nhieu/4n_r_gaussian.jpg', denoise)
# Out:
# True

# %% [markdown]
# DO ẢNH CÒN BỊ BLUR NÊN DÙNG BỘ LỌC WIENER ĐỂ LÀM RÕ LẠI ẢNH

# %%
k2 = cv2.imread('./kernel1.png', 0)
plt.imshow(k2, cmap='gray')

# %%
from skimage import color, data, restoration

# %% [markdown]
# ÁP DỤNG BỘ LỌC WIENER

# %%
deconvolved_img = restoration.wiener(denoise, k2, 50000000)
plt.imshow(deconvolved_img, cmap='gray')

# %% [markdown]
# TÍNH MSE

# %%
import math
from skimage import img_as_float
from skimage.measure import compare_mse as mse

# %%
anh_goc = cv2.imread('./Anh nhieu/4g.jpg', 0)
plt.imshow(anh_goc, cmap='gray')

# %%
mse_noise = math.sqrt(mse(img_as_float(img), img_as_float(anh_goc)))
mse_noise
# Out:
# C:\Users\baole\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:1: UserWarning: DEPRECATED: skimage.measure.compare_mse has been moved to skimage.metrics.mean_squared_error. It will be removed from skimage.measure in version 0.18.
#   """Entry point for launching an IPython kernel.
# 0.05713347038828411

# %%
mse_denoise = math.sqrt(mse(img_as_float(denoise), img_as_float(anh_goc)))
mse_denoise
# Out:
# C:\Users\baole\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:1: UserWarning: DEPRECATED: skimage.measure.compare_mse has been moved to skimage.metrics.mean_squared_error. It will be removed from skimage.measure in version 0.18.
#   """Entry point for launching an IPython kernel.
# 0.056853975788114706
